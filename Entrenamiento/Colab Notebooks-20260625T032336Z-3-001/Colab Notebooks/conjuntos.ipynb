# %%
frutas_amarillas=["naranja", "piña", "maracuyá","mango"]
frutos_varios=["guayaba", "fresa", "manzana", "uva", "piña", "maracuyá"]
a = set (frutas_amarillas)
b = set (frutos_varios)
union = list(a | b)
print (union)
soloA = list(a - b) #elementos de a que no están en b
print (soloA)
soloB = list(b - a) # elementos de b que no están en a
print (soloB)
interseccion = (a & b)
print (interseccion)
# Out:
# ['piña', 'guayaba', 'naranja', 'manzana', 'maracuyá', 'mango', 'fresa', 'uva']
# ['mango', 'naranja']
# ['manzana', 'uva', 'guayaba', 'fresa']
# {'maracuyá', 'piña'}
