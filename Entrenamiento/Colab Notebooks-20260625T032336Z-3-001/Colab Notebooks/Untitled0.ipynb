# %%
import pandas as pd

# %%
data1 = {
    'Empresa_transp': ['Transporte_Norte'] * 30 + ['Transporte_Monky'] * 20,
    'Punto_dist': list(range(1, 31)) + list(range(1, 21)),
    'Id_camion': [
        4, 1, 5, 4, 2, 4, 2, 1, 4, 5, 1, 5, 4, 1, 3, 4, 3, 1, 2, 4, 2, 3, 1, 4, 3, 1, 5, 2, 1, 2,
        1, 4, 4, 4, 4, 4, 2, 4, 2, 3, 3, 1, 1, 3, 2, 1, 2, 3, 4, 4
    ],
    'cajas_entrega': [
        1492, 1359, 1289, 1325, 1368, 1233, 1450, 1325, 1279, 1425, 1362, 1382, 1213, 1377, 1378, 1237, 1344, 1276, 1446, 1274, 1397, 1387, 1480, 1360, 1472, 1417, 1359, 1317, 1360, 1363,
        85, 88, 93, 87, 98, 100, 92, 93, 88, 97, 90, 91, 92, 89, 97, 96, 89, 100, 91, 85
    ],
    'Tiempo_despacho': [
        31, 39, 54, 30, 55, 34, 38, 41, 55, 53, 39, 51, 39, 42, 47, 42, 51, 38, 35, 49, 39, 42, 34, 30, 50, 31, 47, 52, 35, 43,
        11, 14, 14, 14, 14, 13, 10, 11, 10, 14, 12, 10, 15, 12, 13, 14, 12, 12, 12, 15
    ]
}
df1 = pd.DataFrame(data1)
display(df1)
# Out:
#       Empresa_transp  Punto_dist  Id_camion  cajas_entrega  Tiempo_despacho
# 0   Transporte_Norte           1          4           1492               31
# 1   Transporte_Norte           2          1           1359               39
# 2   Transporte_Norte           3          5           1289               54
# 3   Transporte_Norte           4          4           1325               30
# 4   Transporte_Norte           5          2           1368               55
# 5   Transporte_Norte           6          4           1233               34
# 6   Transporte_Norte           7          2           1450               38
# 7   Transporte_Norte           8          1           1325               41
# 8   Transporte_Norte           9          4           1279               55
# 9   Transporte_Norte          10          5           1425               53
# 10  Transporte_Norte          11          1           1362               39
# ...

# %%
data2 = {
    'Empresa_transp': ['Transporte_Norte'] * 30 + ['Transporte_Monky'] * 20,
    'Punto_dist': list(range(1, 31)) + list(range(1, 21)),
    'Id_camion': [
        4, 1, 5, 4, 2, 4, 2, 1, 4, 5, 1, 5, 4, 1, 3, 4, 3, 1, 2, 4, 2, 3, 1, 4, 3, 1, 5, 2, 1, 2,
        1, 4, 4, 4, 4, 4, 2, 4, 2, 3, 3, 1, 1, 3, 2, 1, 2, 3, 4, 4
    ],
    'cajas_entrega': [
        1126, 1241, 1380, 1382, 1139, 1264, 1236, 1416, 1324, 1390, 1307, 1415, 1310, 1168, 1266, 1169, 1162, 1376, 1303, 1162, 1357, 1427, 1141, 1180, 1363, 1172, 1341, 1296, 1435, 1177,
        83, 86, 93, 81, 85, 95, 93, 83, 83, 87, 95, 82, 85, 82, 85, 92, 81, 86, 86, 91
    ],
    'Tiempo_despacho': [
        38, 48, 42, 34, 51, 37, 54, 35, 40, 42, 34, 35, 45, 35, 50, 34, 34, 38, 55, 50, 42, 41, 35, 32, 44, 43, 38, 54, 44, 37,
        11, 10, 15, 11, 11, 14, 11, 15, 12, 13, 14, 12, 12, 10, 10, 11, 14, 13, 15, 13
    ]
}
df2 = pd.DataFrame(data2)
display(df2)
# Out:
#       Empresa_transp  Punto_dist  Id_camion  cajas_entrega  Tiempo_despacho
# 0   Transporte_Norte           1          4           1126               38
# 1   Transporte_Norte           2          1           1241               48
# 2   Transporte_Norte           3          5           1380               42
# 3   Transporte_Norte           4          4           1382               34
# 4   Transporte_Norte           5          2           1139               51
# 5   Transporte_Norte           6          4           1264               37
# 6   Transporte_Norte           7          2           1236               54
# 7   Transporte_Norte           8          1           1416               35
# 8   Transporte_Norte           9          4           1324               40
# 9   Transporte_Norte          10          5           1390               42
# 10  Transporte_Norte          11          1           1307               34
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of 'cajas_entrega' in df2
plt.figure(figsize=(10, 6))
sns.histplot(df2['cajas_entrega'], kde=True, color='purple')
plt.title('Distribución de Cajas de Entrega en df2')
plt.xlabel('Cajas de Entrega')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
# Distribution of 'Tiempo_despacho' in df2
plt.figure(figsize=(10, 6))
sns.histplot(df2['Tiempo_despacho'], kde=True, color='green')
plt.title('Distribución de Tiempo de Despacho en df2')
plt.xlabel('Tiempo de Despacho')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
